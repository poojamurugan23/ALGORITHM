# %% [markdown]
# <a href="https://colab.research.google.com/github/poojamurugan23/GitHub-pooja/blob/main/Linear_search_by_pooja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1
# Generate random lists of different sizes
list_sizes = [2,5,9,22,27,90]
search_times = []

for n in list_sizes:
    # Create a random list of size n
    arr = [random.randint(1, 10000) for _ in range(n)]

    # Choose a random element to search for
    x = random.choice(arr)

    # Start the timer
    start_time = time.time()

    # Perform linear search
    linear_search(arr, x)

    # Stop the timer and record the time
    end_time = time.time()
    search_time = end_time - start_time
    search_times.append(search_time)
# Plot the results
plt.plot(list_sizes, search_times)
plt.xlabel("List Size (n)")
plt.ylabel("Search Time (seconds)")
plt.title("Linear Search Time Complexity")
plt.show()
